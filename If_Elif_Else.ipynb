# %% [markdown]
# <a href="https://colab.research.google.com/github/ekyndr/PSDS-DASAR/blob/main/If_Elif_Else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## percabangan/struktur pemilihan

# %% [markdown]
# pada bagian ini, kamu akan membuat keputusan pada bahasa pemograman pyhton menggunakan struktur percabangan atau juga sering disebut IF ELSE statment. pengambilan keputusan dibutuhkan ketika kamu akan mengeksekusi suatu kode jika sebuah kondisi tertentu di penuhi
#
#
#
# >
# statement if.. elif..else digunakan pada pyhton untuk mengambil keputussan

# %% [markdown]
# # IF Statement

# %% [markdown]
# python IF statement syntax
#
# ```
# # if test expression:
#      statement(s)
# ```

# %% [markdown]
# python IF statement flowchart

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **example:pyhton if statement**

# %%
#jika angka bilangan positif maka print "adalah bilangan positif"

angka = 3
if angka> 0:
  print(angka, 'adalah bilngan positif')
print('pernyataan ini juga selalu di tampilkan')
angka = -1
if angka< 0:
  print(angka, 'adalah bilngan negatif')
print('pernyataan ini juga selalu di tampilkan')
# Out:
# 3 adalah bilngan positif
# pernyataan ini juga selalu di tampilkan
# -1 adalah bilngan negatif
# pernyataan ini juga selalu di tampilkan

# %% [markdown]
# #IF ELSE statement

# %% [markdown]
# python IF ELSE STATEMENT
#
#
# ```
# # if test expression:
#   body of if
# else:
#   body of else

# %% [markdown]
# pyhton if else statement flowchart

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **example : python if else statement**

# %%
# program disusun untuk menecek apakah angka tersebut kurang dari 0 atau tidak
# dan menampilkan tulisan yang sesuai
angka=3
if angka >= 0:
   print('bilangan lebih dari atau samadengan 0')

else :
   print('bilangan kurang dari 0')
# Out:
# bilangan lebih dari atau samadengan 0

# %%
#Program disusun untuk mengecek apakah dua buah angka sama atau tidak sama
#dan menampilkan tulisan yang sesuai
a = 5
b = 5
if a==b :
  print('a dan b bernilai sama')
else:
  print('a dan b bernilai berbeda')
  print('belajar IF ELSE')
# Out:
# a dan b bernilai sama

# %%
#program disusun untukk mengecek apakah perbandingan dua buah angka
#dan menampilkan tulisan yang sesuai
# membaca dua angka
bil1 = int(input('masukkan bilangan pertama :'))
bil2 = int(input('masukkan bikangan kedua '))
# memilih bilangan yang lebih bedar
if bil1>bil2:
  bil_lebih_besar = bil1
else :
  bil_lebih_besar = bil2
#menampilkan hasil
print('bilangan yang lebih besar adalah:',bil_lebih_besar)
# Out:
# masukkan bilangan pertama :3
# masukkan bikangan kedua 5
# bilangan yang lebih besar adalah: 5

# %% [markdown]
# #IF ELIF ELSE statement

# %% [markdown]
# pyhton IF ELIF ELSE statement
#
#
# ```
# # if test expression:
#      body of if
#   elif test expression:
#      body of elif
#   else:
#      body of else
# ```

# %% [markdown]
# IF ELIF ELSE statement flowchart

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **example : python IF ELIF ELSE statement**

# %%
#program disusun untuk mengecek apakah merupakan bilangan positif,negatif,atau nol
#dan menampilkan tulisan yang sesuai
angka = 3.4
if angka > 0 :
  print('bilangan positif')
elif angka == 0:
  print('nol')
else:
  print('bilangan negatif')
# Out:
# bilangan positif

# %%
#statement if
x = 4
if x %2 ==0: #jika di bagi 3 sisanya samadengan 0
  print('x habis di bagi dua')

# statement if ... elif...else
x = 7
if x % 2 == 0: #jika x dibagi 2 sisanya samadengan 0
  print('x habis di bagi dua')
elif x % 3==0: #jika x dibagi 3 sisanya samadengan 0
  print(' x habis di bagi tiga')
elif x%5 == 0: #jika x dibagi 5 sisanya samadengan 0
  print('x habis di bagi lima')
else:
  print('x tidak habis dibagi dua,tiga,ataupun lima')
# Out:
# x habis di bagi dua
# x tidak habis dibagi dua,tiga,ataupun lima

# %% [markdown]
# # python nested IF statement

# %% [markdown]
# **example : python nested if statement**

# %%
#program disusun untuk mengecek apakah merupakan bilangan positif,negatif,atau nol
#dan menampilkan tulisan yang sesuai
angka = float(input('masukkan angka:'))
if angka >= 0 :
  if angka == 0:
     print('nol')
  else:
     print('bilangan positif')
else :
  print('bilangan negatif')
# Out:
# masukkan angka:4
# bilangan positif

# %% [markdown]
# # Latihan

# %% [markdown]
# buatlah sebuah fungsi "Mahal_Diskon" dengan ketentuan:
#
# *   input berupa data produk dengan tipe numerik tunggal
# *   kategori input adalah "murah" dan "mahal", kemudian diskon ada 3 kategori 10%,20%,dan 40%
# * output pertama sebuah teks/string yang menyatakan "mahal" atau "murah" dan keterangan "kam mendaptkan diskon.."
# * output kedua adalah harga yang perlu dibayarkan

# %%
#ketikkan codingan anda
def mahal_diskon(harga):
  opini = input('apakah menurut anda murah atau mahal?:')
  if opini == "murah":
    a = int(input('berapa diskon  yang ingin anda ambil 10%,20%, atau 40%:'))
    if a == 10:
      print("murah")
      print('anda mendapatkan diskon',a,"%")
      diskon= harga*0.1
      total = harga-diskon
      print('harga yang perlu di bayar Rp.',total)
    elif a == 20:
      print("murah")
      print('anda mendapatkan diskon',a,"%")
      diskon= harga*0.2
      total = harga-diskon
      print('harga yang perlu di bayar Rp.',total)
    else:
      print("murah")
      print('anda mendapatkan diskon',a,"%")
      diskon= harga*0.4
      total = harga-diskon
      print('harga yang perlu di bayar Rp.',total)
  else:
    a = int(input('berapa diskon  yang ingin anda ambil 10%,20%, atau 40%:'))
    if a == 10:
      print("mahal")
      print('anda mendapatkan diskon',a,"%")
      diskon= harga*0.1
      total = harga-diskon
      print('harga yang perlu di bayar Rp.',total)
    elif a == 20:
      print("mahal")
      print('anda mendapatkan diskon',a,"%")
      diskon= harga*0.2
      total = harga-diskon
      print('harga yang perlu di bayar Rp.',total)
    else:
      print("mahal")
      print('anda mendapatkan diskon',a,"%")
      diskon= harga*0.4
      total = harga-diskon
      print('harga yang perlu di bayar Rp.',total)
mahal_diskon(15000000)
# Out:
# apakah menurut anda murah atau mahal?:mahal
# berapa diskon  yang ingin anda ambil 10%,20%, atau 40%:20
# mahal
# anda mendapatkan diskon 20 %
# harga yang perlu di bayar Rp. 12000000.0

# %%
harga_produk = int(input('masukan harga produk:'))
if harga_produk >= 250000:
  if harga_produk >850000:
    print('mahal!!', 'kamu mendapatkan diskon 40%')
    diskon = harga_produk*0.4
    total = harga_produk-diskon
  else :
    print('mahal!!','kamu mendapatkan diskon 20%')
    diskon = harga_produk*0.2
    total = harga_produk-diskon
else :
    print('murah','kamu mendapatkan diskon 10%')
    diskon = harga_produk*0.1
    total = harga_produk-diskon
print('total yang harus kamu bayar',total)
# Out:
# masukan harga produk:123000
# murah kamu mendapatkan diskon 10%
# total yang harus kamu bayar 110700.0
